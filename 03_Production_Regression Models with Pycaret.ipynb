# %% [markdown]
# ## Production

# %% [markdown]
# This code should be running on server or in cloud

# %%
from pycaret.regression import *
import pandas as pd

# %%
new_data = pd.read_csv('/2_Automating the ML Model Cycle/diamond_dataset_predict_label.csv', 
                       header = 0,
                       sep = ',')

# %%
new_data.head()
# Out:
#    Carat Weight        Cut Color Clarity Polish Symmetry Report
# 0          1.51      Ideal     D     VS1     ID       ID   AGSL
# 1          1.26      Ideal     G     VS2     ID       ID   AGSL
# 2          1.20      Ideal     I     VS2     EX       VG    GIA
# 3          1.04  Very Good     G     SI1     VG       VG    GIA
# 4          1.07  Very Good     H    VVS2     EX       ID   AGSL

# %%
saved_final_lightgbm = load_model('diamond-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_lightgbm, data=new_data)

# %%
new_prediction.tail(15)
# Out:
#      Carat Weight        Cut Color Clarity Polish Symmetry Report  \
# 385          1.20  Very Good     E     SI1     EX       VG    GIA
# 386          1.40  Very Good     D      IF     VG        G    GIA
# 387          1.71       Good     I     SI1     VG       VG    GIA
# 388          2.03      Ideal     D      IF     EX       VG    GIA
# 389          0.90       Good     H     SI1     VG        G    GIA
# 390          1.50  Very Good     H     SI1     VG       VG    GIA
# 391          1.09      Ideal     D    VVS2     EX       EX    GIA
# 392          1.32      Ideal     G     VS1     EX       EX    GIA
# 393          1.10      Ideal     F     VS1     EX       VG    GIA
# 394          1.41      Ideal     G     SI1     EX       EX    GIA
# 395          1.70  Very Good     G     VS1     VG        G    GIA
# 396          0.91       Fair     G     SI1     VG       VG    GIA
# 397          1.57      Ideal     I    VVS2     VG       VG    GIA
# 398          2.02  Very Good     G     VS1      G        G    GIA
# 399          1.61  Very Good     I      IF     VG       VG    GIA
#
#      prediction_label
# 385      10058.527393
# 386      21676.988299
# 387      14058.421776
# 388      59089.992686
# 389       4087.325257
# 390       8268.641447
# 391       8795.452285
# 392      11684.178962
# 393       6683.737821
# 394       9859.837428
# 395      24598.301280
# 396       4277.179546
# 397       8634.534866
# 398      23627.907741
# 399       8848.957159
