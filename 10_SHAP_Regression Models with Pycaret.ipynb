# %% [markdown]
# # Regression Models with Pycaret

# %% [markdown]
# #### Get data

# %%
from pycaret.regression import *

# %%
# load the dataset from pycaret
from pycaret.datasets import get_data
dataset = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# #### EDA

# %%
dataset = get_data('diamond')

# %%
data = dataset.sample(frac=0.9, random_state=786)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (5400, 8)
# Unseen Data For Predictions (600, 8)

# %% [markdown]
# #### Preprocessing

# %%
# initialize setup

exp_reg102 = setup(data = data, target = 'Price', 
                   session_id=123,
                   normalize = True, 
                   transformation = True, transform_target = True, 
                   remove_multicollinearity = True, multicollinearity_threshold = 0.95, 
                   bin_numeric_features = ['Carat Weight'],
                   log_experiment = True, experiment_name = 'diamond1')
# Out:
# <style type="text/css">
# #T_f9923_row10_col1, #T_f9923_row16_col1, #T_f9923_row18_col1, #T_f9923_row20_col1, #T_f9923_row22_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f9923">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9923_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f9923_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9923_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9923_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f9923_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9923_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f9923_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9923_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f9923_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9923_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f9923_row3_col1" class="data row3 col1" >(5400, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9923_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f9923_row4_col1" class="data row4 col1" >(5400, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9923_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f9923_row5_col1" class="data row5 col1" >(3779, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f9923_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f9923_row6_col1" class="data row6 col1" >(1621, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f9923_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_f9923_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f9923_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_f9923_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f9923_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_f9923_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f9923_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f9923_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f9923_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f9923_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f9923_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f9923_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f9923_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f9923_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f9923_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_f9923_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f9923_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_f9923_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f9923_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_f9923_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f9923_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_f9923_row17_col1" class="data row17 col1" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f9923_row18_col0" class="data row18 col0" >Transformation</td>
#       <td id="T_f9923_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f9923_row19_col0" class="data row19 col0" >Transformation method</td>
#       <td id="T_f9923_row19_col1" class="data row19 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f9923_row20_col0" class="data row20 col0" >Normalize</td>
#       <td id="T_f9923_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f9923_row21_col0" class="data row21 col0" >Normalize method</td>
#       <td id="T_f9923_row21_col1" class="data row21 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f9923_row22_col0" class="data row22 col0" >Transform target</td>
#       <td id="T_f9923_row22_col1" class="data row22 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f9923_row23_col0" class="data row23 col0" >Transform target method</td>
#       <td id="T_f9923_row23_col1" class="data row23 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f9923_row24_col0" class="data row24 col0" >Fold Generator</td>
#       <td id="T_f9923_row24_col1" class="data row24 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f9923_row25_col0" class="data row25 col0" >Fold Number</td>
#       <td id="T_f9923_row25_col1" class="data row25 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f9923_row26_col0" class="data row26 col0" >CPU Jobs</td>
#       <td id="T_f9923_row26_col1" class="data row26 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f9923_row27_col0" class="data row27 col0" >Use GPU</td>
#       <td id="T_f9923_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f9923_row28_col0" class="data row28 col0" >Log Experiment</td>
#       <td id="T_f9923_row28_col1" class="data row28 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f9923_row29_col0" class="data row29 col0" >Experiment Name</td>
#       <td id="T_f9923_row29_col1" class="data row29 col1" >diamond1</td>
#     </tr>
#     <tr>
#       <th id="T_f9923_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f9923_row30_col0" class="data row30 col

# %% [markdown]
# #### Model Training

# %%
best_model = compare_models(exclude = ['ransac'])
# Out:
# <style type="text/css">
# #T_578ef th {
#   text-align: left;
# }
# #T_578ef_row0_col0, #T_578ef_row0_col1, #T_578ef_row0_col6, #T_578ef_row1_col0, #T_578ef_row1_col2, #T_578ef_row1_col3, #T_578ef_row1_col4, #T_578ef_row1_col5, #T_578ef_row2_col0, #T_578ef_row2_col1, #T_578ef_row2_col2, #T_578ef_row2_col3, #T_578ef_row2_col4, #T_578ef_row2_col5, #T_578ef_row2_col6, #T_578ef_row3_col0, #T_578ef_row3_col1, #T_578ef_row3_col2, #T_578ef_row3_col3, #T_578ef_row3_col4, #T_578ef_row3_col5, #T_578ef_row3_col6, #T_578ef_row4_col0, #T_578ef_row4_col1, #T_578ef_row4_col2, #T_578ef_row4_col3, #T_578ef_row4_col4, #T_578ef_row4_col5, #T_578ef_row4_col6, #T_578ef_row5_col0, #T_578ef_row5_col1, #T_578ef_row5_col2, #T_578ef_row5_col3, #T_578ef_row5_col4, #T_578ef_row5_col5, #T_578ef_row5_col6, #T_578ef_row6_col0, #T_578ef_row6_col1, #T_578ef_row6_col2, #T_578ef_row6_col3, #T_578ef_row6_col4, #T_578ef_row6_col5, #T_578ef_row6_col6, #T_578ef_row7_col0, #T_578ef_row7_col1, #T_578ef_row7_col2, #T_578ef_row7_col3, #T_578ef_row7_col4, #T_578ef_row7_col5, #T_578ef_row7_col6, #T_578ef_row8_col0, #T_578ef_row8_col1, #T_578ef_row8_col2, #T_578ef_row8_col3, #T_578ef_row8_col4, #T_578ef_row8_col5, #T_578ef_row8_col6, #T_578ef_row9_col0, #T_578ef_row9_col1, #T_578ef_row9_col2, #T_578ef_row9_col3, #T_578ef_row9_col4, #T_578ef_row9_col5, #T_578ef_row9_col6, #T_578ef_row10_col0, #T_578ef_row10_col1, #T_578ef_row10_col2, #T_578ef_row10_col3, #T_578ef_row10_col4, #T_578ef_row10_col5, #T_578ef_row10_col6, #T_578ef_row11_col0, #T_578ef_row11_col1, #T_578ef_row11_col2, #T_578ef_row11_col3, #T_578ef_row11_col4, #T_578ef_row11_col5, #T_578ef_row11_col6, #T_578ef_row12_col0, #T_578ef_row12_col1, #T_578ef_row12_col2, #T_578ef_row12_col3, #T_578ef_row12_col4, #T_578ef_row12_col5, #T_578ef_row12_col6, #T_578ef_row13_col0, #T_578ef_row13_col1, #T_578ef_row13_col2, #T_578ef_row13_col3, #T_578ef_row13_col4, #T_578ef_row13_col5, #T_578ef_row13_col6, #T_578ef_row14_col0, #T_578ef_row14_col1, #T_578ef_row14_col2, #T_578ef_row14_col3, #T_578ef_row14_col4, #T_578ef_row14_col5, #T_578ef_row14_col6, #T_578ef_row15_col0, #T_578ef_row15_col1, #T_578ef_row15_col2, #T_578ef_row15_col3, #T_578ef_row15_col4, #T_578ef_row15_col5, #T_578ef_row15_col6, #T_578ef_row16_col0, #T_578ef_row16_col1, #T_578ef_row16_col2, #T_578ef_row16_col3, #T_578ef_row16_col4, #T_578ef_row16_col5, #T_578ef_row16_col6 {
#   text-align: left;
# }
# #T_578ef_row0_col2, #T_578ef_row0_col3, #T_578ef_row0_col4, #T_578ef_row0_col5, #T_578ef_row1_col1, #T_578ef_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_578ef_row0_col7, #T_578ef_row1_col7, #T_578ef_row2_col7, #T_578ef_row3_col7, #T_578ef_row5_col7, #T_578ef_row6_col7, #T_578ef_row7_col7, #T_578ef_row8_col7, #T_578ef_row9_col7, #T_578ef_row10_col7, #T_578ef_row11_col7, #T_578ef_row12_col7, #T_578ef_row13_col7, #T_578ef_row14_col7, #T_578ef_row15_col7, #T_578ef_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_578ef_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_578ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_578ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_578ef_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_578ef_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_578ef_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_578ef_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_578ef_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_578ef_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_578ef_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_578ef_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_578ef_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_578ef_row0_col1" class="data row0 col1" >1707.9544</td>
#       <td id="T_578ef_row0_col2" class="data row0 col2" >5903344.1271</td>
#       <td id="T_578ef_row0_col3" class="data row0 col3" >2417.2365</td>
#       <td id="T_578ef_row0_col4" class="data row0 col4" >0.9413</td>
#       <td id="T_578ef_row0_col5" class="data row0 col5" >0.2225</td>
#       <td id="T_578ef_row0_col6" class="data row0 col6" >0.1887</td>
#       <td id="T_578ef_row0_col7" class="data row0 col7" >0.2320</td>
#     </tr>
#     <tr>
#       <th id="T_578ef_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_578ef_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_578ef_row1_col1" class="data row1 col1" >1660.9066</td>
#       <td id="T_578ef_row1_col2" class="data row1 col2" >6358156.8678</td>
#       <td id="T_578ef_row1_col3" class="data row1 col3" >2495.2445</td>
#       <td id="T_578ef_row1_col4" class="data row1 col4" >0.9377</td>
#       <td id="T_578ef_row1_col5" class="data row1 col5" >0.2235</td>
#       <td id="T_578ef_row1_col6" class="data row1 col6" >0.1842</td>
#       <td id="T_578ef_row1_col7" class="data row1 col7" >0.2430</td>
#     </tr>
#     <tr>
#       <th id="T_578ef_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_578ef_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_578ef_row2_col1" class="data row2 col1" >1741.3787</td>
#       <td id="T_578ef_row2_col2" class="data row2 col2" >7137302.0316</td>
#       <td id="T_578ef_row2_col3" class="data row2 col3" >2652.7687</td>
#       <td id="T_578ef_row2_col4" class="data row2 col4" >0.9301</td>
#       <td id="T_578ef_row2_col5" class="data row2 col5" >0.2402</td>
#       <td id="T_578ef_row2_col6" class="data row2 col6" >0.1914</td>
#       <td id="T_578ef_row2_col7" class="data row2 col7" >0.4210</td>
#     </tr>
#     <tr>
#       <th id="T_578ef_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_578ef_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_578ef_row3_col1" class="data row3 col1" >1899.5518</td>
#       <td id="T_578ef_row3_col2" class="data row3 col2" >8861962.0801</td>
#       <td id="T_578ef_row3_col3" class="data row3 col3" >2964.1057</td>
#       <td id="T_578ef_row3_col4" class="data row3 col4" >0.9123</td>
#       <td id="T_578ef_row3_col5" class="data row3 col5" >0.2605</td>
#       <td id="T_578ef_row3_col6" class="data row3 col6" >0.2042</td>
#       <td id="T_578ef_row3_col7" class="data row3 col7" >0.4330</td>
#     </tr>
#     <tr>
#       <th id="T_578ef_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_578ef_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_578ef_row4_col1" class="data row4 col1" >1917.2621</td>
#       <td id="T_578ef_row4_col2" class="data row4 col2" >9348381.9398</td>
#       <td id="T_578ef_row4_col3" class="data row4 col3" >3041.8356</td>
#       <td id="T_578ef_row4_col4" class="data row4 col4" >0.9078</td>
#       <td id="T_578ef_row4_col5" class="data row4 col5" >0.2611</td>
#       <td id="T_578ef_row4_col6" class="data row4 col6" >0.2045</td>
#       <td id="T_578ef_row4_col7" class="data row4 col7" >0.1320</td>
#     </tr>
#     <tr>
#       <th id="T_578ef_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_578ef_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_578ef_row5_col1" class="data row5 col1" >2459.0362</td>
#       <td id="T_578ef_row5_col2" class="data row5 col2" >13448255.5674</td>
#       <td id="T_578ef_row5_col3" class="data row5 col3" >3652.8315</td>
#       <td id="T_578ef_row5_col4" class="data row5 col4" >0.8665</td>
#       <td id="T_578ef_row5_col5" class="data row5 col5" >0.2773</td>
#       <td id="T_578ef_row5_col6" class="data row5 col6" >0.2450</td>
#       <td id="T_578ef_row5_col7" class="data row5 col7" >0.1450</td>
#     </tr>
#     <tr>
#       <th id="T_578ef_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_578ef_row6_col0" class="data ro

# %%
tuned_best = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_f2d7d_row10_col0, #T_f2d7d_row10_col1, #T_f2d7d_row10_col2, #T_f2d7d_row10_col3, #T_f2d7d_row10_col4, #T_f2d7d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f2d7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2d7d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f2d7d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f2d7d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f2d7d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f2d7d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f2d7d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2d7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2d7d_row0_col0" class="data row0 col0" >1679.0225</td>
#       <td id="T_f2d7d_row0_col1" class="data row0 col1" >5267570.3128</td>
#       <td id="T_f2d7d_row0_col2" class="data row0 col2" >2295.1188</td>
#       <td id="T_f2d7d_row0_col3" class="data row0 col3" >0.9422</td>
#       <td id="T_f2d7d_row0_col4" class="data row0 col4" >0.2189</td>
#       <td id="T_f2d7d_row0_col5" class="data row0 col5" >0.1822</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2d7d_row1_col0" class="data row1 col0" >1966.8693</td>
#       <td id="T_f2d7d_row1_col1" class="data row1 col1" >12919474.9145</td>
#       <td id="T_f2d7d_row1_col2" class="data row1 col2" >3594.3671</td>
#       <td id="T_f2d7d_row1_col3" class="data row1 col3" >0.9010</td>
#       <td id="T_f2d7d_row1_col4" class="data row1 col4" >0.2313</td>
#       <td id="T_f2d7d_row1_col5" class="data row1 col5" >0.1945</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2d7d_row2_col0" class="data row2 col0" >1836.1748</td>
#       <td id="T_f2d7d_row2_col1" class="data row2 col1" >7936481.8015</td>
#       <td id="T_f2d7d_row2_col2" class="data row2 col2" >2817.1762</td>
#       <td id="T_f2d7d_row2_col3" class="data row2 col3" >0.9272</td>
#       <td id="T_f2d7d_row2_col4" class="data row2 col4" >0.2408</td>
#       <td id="T_f2d7d_row2_col5" class="data row2 col5" >0.2054</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2d7d_row3_col0" class="data row3 col0" >1679.5022</td>
#       <td id="T_f2d7d_row3_col1" class="data row3 col1" >5620524.0428</td>
#       <td id="T_f2d7d_row3_col2" class="data row3 col2" >2370.7644</td>
#       <td id="T_f2d7d_row3_col3" class="data row3 col3" >0.9380</td>
#       <td id="T_f2d7d_row3_col4" class="data row3 col4" >0.2139</td>
#       <td id="T_f2d7d_row3_col5" class="data row3 col5" >0.1786</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2d7d_row4_col0" class="data row4 col0" >1723.3571</td>
#       <td id="T_f2d7d_row4_col1" class="data row4 col1" >5921593.8542</td>
#       <td id="T_f2d7d_row4_col2" class="data row4 col2" >2433.4325</td>
#       <td id="T_f2d7d_row4_col3" class="data row4 col3" >0.9261</td>
#       <td id="T_f2d7d_row4_col4" class="data row4 col4" >0.2317</td>
#       <td id="T_f2d7d_row4_col5" class="data row4 col5" >0.1982</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f2d7d_row5_col0" class="data row5 col0" >1904.1648</td>
#       <td id="T_f2d7d_row5_col1" class="data row5 col1" >13019205.0876</td>
#       <td id="T_f2d7d_row5_col2" class="data row5 col2" >3608.2136</td>
#       <td id="T_f2d7d_row5_col3" class="data row5 col3" >0.8889</td>
#       <td id="T_f2d7d_row5_col4" class="data row5 col4" >0.2263</td>
#       <td id="T_f2d7d_row5_col5" class="data row5 col5" >0.1933</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f2d7d_row6_col0" class="data row6 col0" >1849.4508</td>
#       <td id="T_f2d7d_row6_col1" class="data row6 col1" >8032177.3277</td>
#       <td id="T_f2d7d_row6_col2" class="data row6 col2" >2834.1096</td>
#       <td id="T_f2d7d_row6_col3" class="data row6 col3" >0.9245</td>
#       <td id="T_f2d7d_row6_col4" class="data row6 col4" >0.2285</td>
#       <td id="T_f2d7d_row6_col5" class="data row6 col5" >0.1930</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f2d7d_row7_col0" class="data row7 col0" >1364.8422</td>
#       <td id="T_f2d7d_row7_col1" class="data row7 col1" >4934572.8565</td>
#       <td id="T_f2d7d_row7_col2" class="data row7 col2" >2221.3898</td>
#       <td id="T_f2d7d_row7_col3" class="data row7 col3" >0.9376</td>
#       <td id="T_f2d7d_row7_col4" class="data row7 col4" >0.1954</td>
#       <td id="T_f2d7d_row7_col5" class="data row7 col5" >0.1531</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f2d7d_row8_col0" class="data row8 col0" >1799.9373</td>
#       <td id="T_f2d7d_row8_col1" class="data row8 col1" >7083354.7602</td>
#       <td id="T_f2d7d_row8_col2" class="data row8 col2" >2661.4573</td>
#       <td id="T_f2d7d_row8_col3" class="data row8 col3" >0.9304</td>
#       <td id="T_f2d7d_row8_col4" class="data row8 col4" >0.2253</td>
#       <td id="T_f2d7d_row8_col5" class="data row8 col5" >0.1871</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f2d7d_row9_col0" class="data row9 col0" >1758.1728</td>
#       <td id="T_f2d7d_row9_col1" class="data row9 col1" >7004547.9751</td>
#       <td id="T_f2d7d_row9_col2" class="data row9 col2" >2646.6107</td>
#       <td id="T_f2d7d_row9_col3" class="data row9 col3" >0.9333</td>
#       <td id="T_f2d7d_row9_col4" class="data row9 col4" >0.2391</td>
#       <td id="T_f2d7d_row9_col5" class="data row9 col5" >0.2026</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f2d7d_row10_col0" class="data row10 col0" >1756.1494</td>
#       <td id="T_f2d7d_row10_col1" class="data row10 col1" >7773950.2933</td>
#       <td id="T_f2d7d_row10_col2" class="data row10 col2" >2748.2640</td>
#       <td id="T_f2d7d_row10_col3" class="data row10 col3" >0.9249</td>
#       <td id="T_f2d7d_row10_col4" class="data row10 col4" >0.2251</td>
#       <td id="T_f2d7d_row10_col5" class="data row10 col5" >0.1888</td>
#     </tr>
#     <tr>
#       <th id="T_f2d7d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f2d7d_row11_col0" class="data row11 col0" >157.9121</td>
#       <td id="T_f2d7d_row11_col1" class="data row11 col1" >2785024.1493</td>
#       <td id="T_f2d7d_row11_col2" class="data row11 col2" >470.1013</td>
#       <td id="T_f2d7d_row11_col3" class="data row11 col3" >0.0161</td>
#       <td id="T_f2d7d_row11_col4" class="data row11 col4" >0.0126</td>
#       <td id="T_f2d7d_row11_col5" class="data row11 col5" >0.0143</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# #### Individual model training

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_0160c_row10_col0, #T_0160c_row10_col1, #T_0160c_row10_col2, #T_0160c_row10_col3, #T_0160c_row10_col4, #T_0160c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0160c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0160c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0160c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0160c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0160c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0160c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0160c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0160c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0160c_row0_col0" class="data row0 col0" >1631.2197</td>
#       <td id="T_0160c_row0_col1" class="data row0 col1" >4764978.7229</td>
#       <td id="T_0160c_row0_col2" class="data row0 col2" >2182.8831</td>
#       <td id="T_0160c_row0_col3" class="data row0 col3" >0.9477</td>
#       <td id="T_0160c_row0_col4" class="data row0 col4" >0.2273</td>
#       <td id="T_0160c_row0_col5" class="data row0 col5" >0.1848</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0160c_row1_col0" class="data row1 col0" >1786.1408</td>
#       <td id="T_0160c_row1_col1" class="data row1 col1" >8517522.8962</td>
#       <td id="T_0160c_row1_col2" class="data row1 col2" >2918.4796</td>
#       <td id="T_0160c_row1_col3" class="data row1 col3" >0.9347</td>
#       <td id="T_0160c_row1_col4" class="data row1 col4" >0.2257</td>
#       <td id="T_0160c_row1_col5" class="data row1 col5" >0.1875</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0160c_row2_col0" class="data row2 col0" >1678.9553</td>
#       <td id="T_0160c_row2_col1" class="data row2 col1" >5196108.3842</td>
#       <td id="T_0160c_row2_col2" class="data row2 col2" >2279.4974</td>
#       <td id="T_0160c_row2_col3" class="data row2 col3" >0.9523</td>
#       <td id="T_0160c_row2_col4" class="data row2 col4" >0.2389</td>
#       <td id="T_0160c_row2_col5" class="data row2 col5" >0.1997</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0160c_row3_col0" class="data row3 col0" >1641.9054</td>
#       <td id="T_0160c_row3_col1" class="data row3 col1" >4585709.6133</td>
#       <td id="T_0160c_row3_col2" class="data row3 col2" >2141.4270</td>
#       <td id="T_0160c_row3_col3" class="data row3 col3" >0.9494</td>
#       <td id="T_0160c_row3_col4" class="data row3 col4" >0.2129</td>
#       <td id="T_0160c_row3_col5" class="data row3 col5" >0.1765</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0160c_row4_col0" class="data row4 col0" >1669.5466</td>
#       <td id="T_0160c_row4_col1" class="data row4 col1" >6287592.8249</td>
#       <td id="T_0160c_row4_col2" class="data row4 col2" >2507.5073</td>
#       <td id="T_0160c_row4_col3" class="data row4 col3" >0.9216</td>
#       <td id="T_0160c_row4_col4" class="data row4 col4" >0.2293</td>
#       <td id="T_0160c_row4_col5" class="data row4 col5" >0.1919</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0160c_row5_col0" class="data row5 col0" >1739.9398</td>
#       <td id="T_0160c_row5_col1" class="data row5 col1" >8399345.6706</td>
#       <td id="T_0160c_row5_col2" class="data row5 col2" >2898.1625</td>
#       <td id="T_0160c_row5_col3" class="data row5 col3" >0.9283</td>
#       <td id="T_0160c_row5_col4" class="data row5 col4" >0.2197</td>
#       <td id="T_0160c_row5_col5" class="data row5 col5" >0.1862</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0160c_row6_col0" class="data row6 col0" >1846.1307</td>
#       <td id="T_0160c_row6_col1" class="data row6 col1" >8981458.3319</td>
#       <td id="T_0160c_row6_col2" class="data row6 col2" >2996.9081</td>
#       <td id="T_0160c_row6_col3" class="data row6 col3" >0.9156</td>
#       <td id="T_0160c_row6_col4" class="data row6 col4" >0.2294</td>
#       <td id="T_0160c_row6_col5" class="data row6 col5" >0.1871</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0160c_row7_col0" class="data row7 col0" >1254.5156</td>
#       <td id="T_0160c_row7_col1" class="data row7 col1" >3385188.9328</td>
#       <td id="T_0160c_row7_col2" class="data row7 col2" >1839.8883</td>
#       <td id="T_0160c_row7_col3" class="data row7 col3" >0.9572</td>
#       <td id="T_0160c_row7_col4" class="data row7 col4" >0.1903</td>
#       <td id="T_0160c_row7_col5" class="data row7 col5" >0.1479</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0160c_row8_col0" class="data row8 col0" >1651.8998</td>
#       <td id="T_0160c_row8_col1" class="data row8 col1" >6412245.8029</td>
#       <td id="T_0160c_row8_col2" class="data row8 col2" >2532.2413</td>
#       <td id="T_0160c_row8_col3" class="data row8 col3" >0.9370</td>
#       <td id="T_0160c_row8_col4" class="data row8 col4" >0.2195</td>
#       <td id="T_0160c_row8_col5" class="data row8 col5" >0.1779</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0160c_row9_col0" class="data row9 col0" >1708.8119</td>
#       <td id="T_0160c_row9_col1" class="data row9 col1" >7051417.4979</td>
#       <td id="T_0160c_row9_col2" class="data row9 col2" >2655.4505</td>
#       <td id="T_0160c_row9_col3" class="data row9 col3" >0.9329</td>
#       <td id="T_0160c_row9_col4" class="data row9 col4" >0.2423</td>
#       <td id="T_0160c_row9_col5" class="data row9 col5" >0.2026</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0160c_row10_col0" class="data row10 col0" >1660.9066</td>
#       <td id="T_0160c_row10_col1" class="data row10 col1" >6358156.8678</td>
#       <td id="T_0160c_row10_col2" class="data row10 col2" >2495.2445</td>
#       <td id="T_0160c_row10_col3" class="data row10 col3" >0.9377</td>
#       <td id="T_0160c_row10_col4" class="data row10 col4" >0.2235</td>
#       <td id="T_0160c_row10_col5" class="data row10 col5" >0.1842</td>
#     </tr>
#     <tr>
#       <th id="T_0160c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0160c_row11_col0" class="data row11 col0" >150.1367</td>
#       <td id="T_0160c_row11_col1" class="data row11 col1" >1790760.1748</td>
#       <td id="T_0160c_row11_col2" class="data row11 col2" >363.1965</td>
#       <td id="T_0160c_row11_col3" class="data row11 col3" >0.0130</td>
#       <td id="T_0160c_row11_col4" class="data row11 col4" >0.0139</td>
#       <td id="T_0160c_row11_col5" class="data row11 col5" >0.0144</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
lgbm_params = {'num_leaves': np.arange(10,200,10),
                        'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
                        'learning_rate': np.arange(0.1,1,0.1)
                        }

tuned_lightgbm = tune_model(lightgbm, 
                            custom_grid = lgbm_params)
# Out:
# <style type="text/css">
# #T_6c226_row10_col0, #T_6c226_row10_col1, #T_6c226_row10_col2, #T_6c226_row10_col3, #T_6c226_row10_col4, #T_6c226_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6c226">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c226_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6c226_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6c226_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6c226_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6c226_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6c226_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c226_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c226_row0_col0" class="data row0 col0" >1675.2714</td>
#       <td id="T_6c226_row0_col1" class="data row0 col1" >5086398.1446</td>
#       <td id="T_6c226_row0_col2" class="data row0 col2" >2255.3044</td>
#       <td id="T_6c226_row0_col3" class="data row0 col3" >0.9442</td>
#       <td id="T_6c226_row0_col4" class="data row0 col4" >0.2344</td>
#       <td id="T_6c226_row0_col5" class="data row0 col5" >0.1883</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c226_row1_col0" class="data row1 col0" >1795.2791</td>
#       <td id="T_6c226_row1_col1" class="data row1 col1" >8215553.0369</td>
#       <td id="T_6c226_row1_col2" class="data row1 col2" >2866.2786</td>
#       <td id="T_6c226_row1_col3" class="data row1 col3" >0.9370</td>
#       <td id="T_6c226_row1_col4" class="data row1 col4" >0.2363</td>
#       <td id="T_6c226_row1_col5" class="data row1 col5" >0.1923</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c226_row2_col0" class="data row2 col0" >1838.7086</td>
#       <td id="T_6c226_row2_col1" class="data row2 col1" >7425749.0618</td>
#       <td id="T_6c226_row2_col2" class="data row2 col2" >2725.0228</td>
#       <td id="T_6c226_row2_col3" class="data row2 col3" >0.9319</td>
#       <td id="T_6c226_row2_col4" class="data row2 col4" >0.2468</td>
#       <td id="T_6c226_row2_col5" class="data row2 col5" >0.2060</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c226_row3_col0" class="data row3 col0" >1674.8863</td>
#       <td id="T_6c226_row3_col1" class="data row3 col1" >5123457.3518</td>
#       <td id="T_6c226_row3_col2" class="data row3 col2" >2263.5055</td>
#       <td id="T_6c226_row3_col3" class="data row3 col3" >0.9435</td>
#       <td id="T_6c226_row3_col4" class="data row3 col4" >0.2180</td>
#       <td id="T_6c226_row3_col5" class="data row3 col5" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c226_row4_col0" class="data row4 col0" >1700.3237</td>
#       <td id="T_6c226_row4_col1" class="data row4 col1" >6162104.8259</td>
#       <td id="T_6c226_row4_col2" class="data row4 col2" >2482.3587</td>
#       <td id="T_6c226_row4_col3" class="data row4 col3" >0.9231</td>
#       <td id="T_6c226_row4_col4" class="data row4 col4" >0.2358</td>
#       <td id="T_6c226_row4_col5" class="data row4 col5" >0.1948</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6c226_row5_col0" class="data row5 col0" >1748.1738</td>
#       <td id="T_6c226_row5_col1" class="data row5 col1" >8683121.7790</td>
#       <td id="T_6c226_row5_col2" class="data row5 col2" >2946.7137</td>
#       <td id="T_6c226_row5_col3" class="data row5 col3" >0.9259</td>
#       <td id="T_6c226_row5_col4" class="data row5 col4" >0.2272</td>
#       <td id="T_6c226_row5_col5" class="data row5 col5" >0.1892</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6c226_row6_col0" class="data row6 col0" >1926.7462</td>
#       <td id="T_6c226_row6_col1" class="data row6 col1" >10303603.5644</td>
#       <td id="T_6c226_row6_col2" class="data row6 col2" >3209.9227</td>
#       <td id="T_6c226_row6_col3" class="data row6 col3" >0.9032</td>
#       <td id="T_6c226_row6_col4" class="data row6 col4" >0.2382</td>
#       <td id="T_6c226_row6_col5" class="data row6 col5" >0.1893</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6c226_row7_col0" class="data row7 col0" >1331.8388</td>
#       <td id="T_6c226_row7_col1" class="data row7 col1" >4013445.1362</td>
#       <td id="T_6c226_row7_col2" class="data row7 col2" >2003.3585</td>
#       <td id="T_6c226_row7_col3" class="data row7 col3" >0.9492</td>
#       <td id="T_6c226_row7_col4" class="data row7 col4" >0.1965</td>
#       <td id="T_6c226_row7_col5" class="data row7 col5" >0.1521</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6c226_row8_col0" class="data row8 col0" >1716.2054</td>
#       <td id="T_6c226_row8_col1" class="data row8 col1" >6753901.5664</td>
#       <td id="T_6c226_row8_col2" class="data row8 col2" >2598.8270</td>
#       <td id="T_6c226_row8_col3" class="data row8 col3" >0.9337</td>
#       <td id="T_6c226_row8_col4" class="data row8 col4" >0.2287</td>
#       <td id="T_6c226_row8_col5" class="data row8 col5" >0.1845</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6c226_row9_col0" class="data row9 col0" >1729.0230</td>
#       <td id="T_6c226_row9_col1" class="data row9 col1" >7120781.9110</td>
#       <td id="T_6c226_row9_col2" class="data row9 col2" >2668.4793</td>
#       <td id="T_6c226_row9_col3" class="data row9 col3" >0.9322</td>
#       <td id="T_6c226_row9_col4" class="data row9 col4" >0.2524</td>
#       <td id="T_6c226_row9_col5" class="data row9 col5" >0.2082</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6c226_row10_col0" class="data row10 col0" >1713.6456</td>
#       <td id="T_6c226_row10_col1" class="data row10 col1" >6888811.6378</td>
#       <td id="T_6c226_row10_col2" class="data row10 col2" >2601.9771</td>
#       <td id="T_6c226_row10_col3" class="data row10 col3" >0.9324</td>
#       <td id="T_6c226_row10_col4" class="data row10 col4" >0.2314</td>
#       <td id="T_6c226_row10_col5" class="data row10 col5" >0.1883</td>
#     </tr>
#     <tr>
#       <th id="T_6c226_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6c226_row11_col0" class="data row11 col0" >147.6755</td>
#       <td id="T_6c226_row11_col1" class="data row11 col1" >1793374.2978</td>
#       <td id="T_6c226_row11_col2" class="data row11 col2" >344.2771</td>
#       <td id="T_6c226_row11_col3" class="data row11 col3" >0.0124</td>
#       <td id="T_6c226_row11_col4" class="data row11 col4" >0.0148</td>
#       <td id="T_6c226_row11_col5" class="data row11 col5" >0.0149</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ### Evaluate the model

# %%
# check the residuals of trained model
plot_model(tuned_best, plot = 'residuals')

# %%
# check feature importance
plot_model(tuned_best, plot = 'feature')

# %%
plot_model(tuned_best, plot = 'error')

# %%
evaluate_model(tuned_best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Interpretability

# %%
# Global Plot Settings
fig_kwargs={'renderer': 'notebook'}
import matplotlib.pyplot as plt
plt.figure(figsize = (18,9))

interpret = interpret_model(tuned_best)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       3 import matplotlib.pyplot as plt
#       4 plt.figure(figsize = (18,9))
# ----> 6 interpret = interpret_model(tuned_best)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\regression\functional.py:1824, in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1727 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1728 def interpret_model(
#    1729     estimator,
#    (...)
#    1737     **kwargs,
#    1738 ):
#    1739     """
#    1740     This function takes a trained model object and returns an interpretation plot
#    1741     based on the test / hold-out set.
#    (...)
#    1821
#    1822     """
# -> 1824     return _CURRENT_EXPERIMENT.interpret_model(
#    1825         estimator=estimator,
#    1826         plot=plot,
#    1827         feature=feature,
#    1828         observation=observation,
#    1829         use_train_data=use_train_data,
#    1830         X_new_sample=X_new_sample,
#    1831         y_new_sample=y_new_sample,
#    1832         save=save,
#    1833         **kwargs,
#    1834     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\regression\oop.py:2122, in RegressionExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2025 def interpret_model(
#    2026     self,
#    2027     estimator,
#    (...)
#    2035     **kwargs,
#    2036 ):
#    2037     """
#    2038     This function takes a trained model object and returns an interpretation plot
#    2039     based on the test / hold-out set.
#    (...)
#    2119
#    2120     """
# -> 2122     return super().interpret_model(
#    2123         estimator=estimator,
#    2124         plot=plot,
#    2125         feature=feature,
#    2126         observation=observation,
#    2127         use_train_data=use_train_data,
#    2128         X_new_sample=X_new_sample,
#    2129         y_new_sample=y_new_sample,
#    2130         save=save,
#    2131         **kwargs,
#    2132     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4075, in _SupervisedExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4070 shap_models_ids = set(shap_models.keys())
#    4072 if plot in ["summary", "correlation", "reason"] and (
#    4073     model_id not in shap_models_ids
#    4074 ):
# -> 4075     raise TypeError(
#    4076         f"This function only supports tree based models for binary classification: {', '.join(shap_models_ids)}."
#    4077     )
#    4079 # plot type
#    4080 allowed_types = ["summary", "correlation", "reason", "pdp", "msa", "pfi"]
#
# TypeError: This function only supports tree based models for binary classification: dt, rf, et, lightgbm.

# %%
# Global Plot Settings
fig_kwargs={'renderer': 'notebook'}
import matplotlib.pyplot as plt
plt.figure(figsize = (18,9))

interpret = interpret_model(tuned_lightgbm)

# %%
interpret_model(tuned_lightgbm, plot = 'reason', observation = 12)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iPZNM9Y9L0YMWCCD92EMR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.5804646388651227, "outValue": 2.6070840319095283, "link": "identity", "featureNames": ["Carat Weight", "Cut_Ideal", "Cut_Very Good", "Cut_Good", "Cut_Fair", "Cut_Signature-Ideal", "Color_G", "Color_E", "Color_D", "Color_I", "Color_H", "Color_F", "Clarity_SI1", "Clarity_VS1", "Clarity_VVS2", "Clarity_VS2", "Clarity_VVS1", "Clarity_IF", "Clarity_FL", "Polish_ID", "Polish_VG", "Polish_G", "Polish_EX", "Symmetry_VG", "Symmetry_G", "Symmetry_EX", "Report"], "features": {"0": {"effect": 0.029605743096241876, "value": 1.254067902197868}, "1": {"effect": -0.00032205169351138754, "value": -0.8471878615320647}, "2": {"effect": -7.312687730954535e-05, "value": 1.2177508834699537}, "3": {"effect": 4.43911970741958e-05, "value": -0.36487454458122776}, "4": {"effect": 2.7170407165566412e-05, "value": -0.14893000390914024}, "5": {"effect": -6.661853130989805e-05, "value": -0.20471422245573168}, "6": {"effect": 0.0008108197894466141, "value": -0.5815262715755652}, "7": {"effect": -7.776531337156783e-05, "value": -0.38462239455243824}, "8": {"effect": -0.00032671903982301874, "value": -0.3459822303293966}, "9": {"effect": 0.0016068370456072296, "value": -0.4494129617379955}, "10": {"effect": 0.0010119158584109837, "value": -0.4688488436780082}, "11": {"effect": 0.000548233367181205, "value": 2.2638015387412236}, "12": {"effect": -0.00699239864475377, "value": 1.3776814345012145}, "13": {"effect": 0.00039373676341725503, "value": -0.4922142005244223}, "14": {"effect": -9.499753804672973e-05, "value": -0.35691264315637344}, "15": {"effect": 0.0006801335024389835, "value": -0.5998680435440341}, "16": {"effect": -6.264015785775955e-05, "value": -0.2203568894147438}, "17": {"effect": -0.00017044722980740022, "value": -0.19173598674881165}, "19": {"effect": -0.0001133272093171283, "value": -0.33338233492614977}, "20": {"effect": 8.21412853492259e-05, "value": -0.8117335312307357}, "21": {"effect": 8.77930319175768e-05, "value": -0.31847787216199924}, "22": {"effect": 0.0002551190401548568, "value": 1.197882582064023}, "23": {"effect": -0.00026378362073916874, "value": 1.2211064068927473}, "24": {"effect": -2.1016827199555957e-05, "value": -0.42102086287759316}, "25": {"effect": -0.0002509309750323581, "value": -0.7262822129653503}, "26": {"effect": 0.00030118231807956436, "value": 0.3727453822004748}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJKHQFZBOZRNVKEDAPDF4')
#   );
# </script>

# %% [markdown]
# ### Explainer Dashboard

# %%
pip install explainerdashboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: explainerdashboard in c:\users\jalal\appdata\roaming\python\python311\site-packages (0.4.3)
# Requirement already satisfied: click in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (8.1.7)
# Requirement already satisfied: dash-auth in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-bootstrap-components>=1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (1.5.0)
# Requirement already satisfied: dash>=2.10.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (2.14.2)
# Requirement already satisfied: dtreeviz>=2.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (2.2.2)
# Requirement already satisfied: flask-simplelogin in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (0.1.2)
# Requirement already satisfied: Flask-WTF>=1.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (1.2.1)
# Requirement already satisfied: graphviz>=0.18.2 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (0.20.1)
# Requirement already satisfied: joblib in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (1.3.2)
# Requirement already satisfied: jupyter-dash>=0.4.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (0.4.2)
# Requirement already satisfied: numpy<=1.24.4 in c:\programdata\anaconda3\lib\site-packages (from explainerdashboard) (1.24.3)
# Requirement already satisfied: oyaml in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (1.0)
# Requirement already satisfied: pandas>=1.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (1.2.2)
# Requirement already satisfied: shap>=0.42.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (0.44.0)
# Requirement already satisfied: waitress in c:\users\jalal\appdata\roaming\python\python311\site-packages (from explainerdashboard) (2.1.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (2.3.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (3.0.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from dash>=2.10.1->explainerdashboard) (5.9.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (4.8.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from dash>=2.10.1->explainerdashboard) (2.31.0)
# Requirement already satisfied: retrying in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dash>=2.10.1->explainerdashboard) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from dash>=2.10.1->explainerdashboard) (1.5.6)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from dash>=2.10.1->explainerdashboard) (68.0.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from dash>=2.10.1->explainerdashboard) (6.0.0)
# Requirement already satisfied: matplotlib in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dtreeviz>=2.1->explainerdashboard) (3.6.0)
# Requirement already satisfied: colour in c:\users\jalal\appdata\roaming\python\python311\site-packages (from dtreeviz>=2.1->explainerdashboard) (0.1.5)
# Requirement already satisfied: pytest in c:\programdata\anaconda3\lib\site-packages (from dtreeviz>=2.1->explainerdashboard) (7.4.0)
# Requirement already satisfied: itsdangerous in c:\users\jalal\appdata\roaming\python\python311\site-packages (from Flask-WTF>=1.1->explainerdashboard) (2.1.2)
# Requirement already satisfied: wtforms in c:\users\jalal\appdata\roaming\python\python311\site-packages (from Flask-WTF>=1.1->explainerdashboard) (3.1.1)
# Requirement already satisfied: ipython in c:\programdata\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (8.15.0)
# Requirement already satisfied: ipykernel in c:\programdata\anaconda3\lib\site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (6.25.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2023.3.post1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from scikit-learn>=1.1->explainerdashboard) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (2.2.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\programdata\anaconda3\lib\site-packages (from shap>=0.42.1->explainerdashboard) (4.65.0)
# Requirement already satisfied: packaging>20.9 in c:\programdata\anaconda3\lib\site-packages (from shap>=0.42.1->explainerdashboard) (23.1)
# Requirement already satisfied: slicer==0.0.7 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from shap>=0.42.1->explainerdashboard) (0.0.7)
# Requirement already satisfied: numba in c:\users\jalal\appdata\roaming\python\python311\site-packages (from shap>=0.42.1->explainerdashboard) (0.58.1)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from shap>=0.42.1->explainerdashboard) (2.2.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->explainerdashboard) (0.4.6)
# Requirement already satisfied: pyyaml in c:\users\jalal\appdata\roaming\python\python311\site-packages (from oyaml->explainerdashboard) (6.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.10.1->explainerdashboard) (3.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from Flask<3.1,>=1.0.4->dash>=2.10.1->explainerdashboard) (1.6.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.10.1->explainerdashboard) (8.2.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->explainerdashboard) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\lib\site-packages (from Werkzeug<3.1->dash>=2.10.1->explainerdashboard) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->dash>=2.10.1->explainerdashboard) (3.11.0)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.6)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.7.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.18.1)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\programdata\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (3.0.9)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from numba->shap>=0.42.1->explainerdashboard) (0.41.1)
# Requirement already satisfied: iniconfig in c:\programdata\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\programdata\anaconda3\lib\site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=2.10.1->explainerdashboard) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=2.10.1->explainerdashboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=2.10.1->explainerdashboard) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=2.10.1->explainerdashboard) (2023.7.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jalal\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (305.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
dashboard(tuned_lightgbm, display_format = 'inline')
# Out:
# Generating self.shap_explainer = shap.TreeExplainer(model)
# Building ExplainerDashboard..
# WARNING: the number of idxs (=1621) > max_idxs_in_dropdown(=1000). However with your installed version of dash(2.14.2) dropdown search may not work smoothly. You can downgrade to `pip install dash==2.6.2` which should work better for now...
# The explainer object has no decision_trees property. so setting decision_trees=False...
# Warning: calculating shap interaction values can be slow! Pass shap_interaction=False to remove interactions tab.
# Generating layout...
# Calculating shap values...
# Calculating predictions...
# Calculating residuals...
# Calculating absolute residuals...
# Calculating shap interaction values...
# Reminder: TreeShap computational complexity is O(TLD^2), where T is the number of trees, L is the maximum number of leaves in any tree and D the maximal depth of any tree. So reducing these will speed up the calculation.
# Calculating dependencies...
# Calculating importances...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# Starting ExplainerDashboard inline (terminate it with ExplainerDashboard.terminate(8050))
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="1000"
#             height="800"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
